# %%
import pandas as pd
import matplotlib 
# %matplotlib inline

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic.head()
# Out:
#    pclass  survived                                               name  \
# 0       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1       3         0       Riihivouri, Miss. Susanna Juhantytar "Sanni"
# 2       3         1          Davison, Mrs. Thomas Henry (Mary E Finck)
# 3       3         0                       Panula, Master. Urho Abraham
# 4       3         1                          Madsen, Mr. Fridtjof Arne
#
#       sex   age  sibsp  parch   ticket     fare cabin embarked boat  body  \
# 0  female  30.0      1      1   345773  24.1500   NaN        S  NaN   NaN
# 1  female  22.0      0      0  3101295  39.6875   NaN        S  NaN   NaN
# 2  female   NaN      1      0   386525  16.1000   NaN        S   16   NaN
# 3    male   2.0      4      1  3101295  39.6875   NaN        S  NaN   NaN
# 4    male  24.0      0      0  C 17369   7.1417   NaN        S   13   NaN
#
#                         home.dest
# 0                             NaN
# ...

# %%
Analizamos la variabll

# %%
titanic.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
titanic.sex.value_counts().plot('bar')

# %%
pd.get_dummies(titanic[['sex']]).head()
# Out:
#    sex_female  sex_male
# 0           1         0
# 1           1         0
# 2           1         0
# 3           0         1
# 4           0         1

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest', 'sex_female',
#        'sex_male'],
#       dtype='object')

# %%
titanic.corr()['survived'][0]
# Out:
# -0.2729667632319925

# %%
[titanic.corr()['survived'][0]] titanic.corr()['survived'][2:9]
# Out:
# age          -0.325286
# sibsp        -0.296252
# parch        -0.170697
# fare         -0.050884
# body               NaN
# sex_female    0.266216
# sex_male     -0.812149
# Name: survived, dtype: float64

# %%
plt.
titanic.corr()['survived'].plot(kind = 'bar')

# %%
titanic = pd.concat([titanic,pd.get_dummies(titanic[['sex']])], axis=1 )

# %%
pivot_df = titanic.pivot(index= 'sex', columns='age',values='survived')
pivot_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3085851174e9> in <module>
# ----> 1 pivot_df = titanic.pivot(index= 'sex', columns='age',values='survived')
#       2 pivot_df
#
# ~/repos/devenv3/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5626     def pivot(self, index=None, columns=None, values=None):
#    5627         from pandas.core.reshape.pivot import pivot
# -> 5628         return pivot(self, index=index, columns=columns, values=values)
#    5629
#    5630     _shared_docs['pivot_table'] = """
#
# ~/repos/devenv3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     386             indexed = data._constructor_sliced(data[values].values,
#     387                                                index=index)
# --> 388     return indexed.unstack(columns)
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit(titanic[['sex']])
# Out:
# OneHotEncoder(categorical_features=None, categories=None, drop=None,
#               dtype=<class 'numpy.float64'>, handle_unknown='ignore',
#               n_values=None, sparse=True)

# %%
enc.categories_
# Out:
# [array(['female', 'male'], dtype=object)]

# %%
titanic.sex.isnull().sum()
# Out:
# 0

# %%
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# define example
data = ['cold', 'cold', 'warm', 'cold', 'hot', 'hot', 'warm', 'cold', 'warm', 'hot']
values = array(data)
print(values)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
print(integer_encoded)
# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
print(onehot_encoded)
# invert first example
inverted = label_encoder.inverse_transform([argmax(onehot_encoded[0, :])])
print(inverted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-37165a28bc82> in <module>
#       4 # define example
#       5 data = ['cold', 'cold', 'warm', 'cold', 'hot', 'hot', 'warm', 'cold', 'warm', 'hot']
# ----> 6 values = array(data)
#       7 print(values)
#       8 # integer encode
#
# NameError: name 'array' is not defined

# %%
enc.fit_transform(titanic, titanic.sex)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b869423fed97> in <module>
# ----> 1 enc.fit_transform(titanic, titanic.sex)
#
# ~/repos/devenv3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in fit_transform(self, X, y)
#     629                 self._categorical_features, copy=True)
#     630         else:
# --> 631             return self.fit(X).transform(X)
#     632
#     633     def _legacy_transform(self, X):
#
# ~/repos/devenv3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     491             return self
#     492         else:
# --> 493             self._fit(X, handle_unknown=self.handle_unknown)
#     494             self.drop_idx_ = self._compute_drop_idx()
#     495             return self
#
# ...

# %%
titanic
# Out:
#       pclass  survived                                               name  \
# 0          3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1          3         0       Riihivouri, Miss. Susanna Juhantytar "Sanni"
# 2          3         1          Davison, Mrs. Thomas Henry (Mary E Finck)
# 3          3         0                       Panula, Master. Urho Abraham
# 4          3         1                          Madsen, Mr. Fridtjof Arne
# 5          3         1                     Asplund, Miss. Lillian Gertrud
# 6          3         0                                   Kelly, Mr. James
# 7          3         0                                Mernagh, Mr. Robert
# 8          3         0                       Klasen, Miss. Gertrud Emilia
# 9          1         1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 10         3         1                                  Finoli, Mr. Luigi
# 11         3         0                       Skoog, Master. Karl Thorsten
# ...
